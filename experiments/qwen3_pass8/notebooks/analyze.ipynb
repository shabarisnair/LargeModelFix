# %%
import pandas as pd
import json

answers = []
with open("/home/ssn899/Desktop/LargeModelFix/experiments/qwen3_pass8/results/full/generations/Qwen3-30B-A3B-Instruct-2507__aime2024.jsonl", "r") as f:
    for line in f:
        answers.append(json.loads(line))

df = pd.DataFrame(answers)

# %%
print(df['response'][0])
# Out:
# {
#   "steps": [
#     {
#       "step_id": 1,
#       "edge": "The problem defines the scenario: Jen selects 4 distinct numbers from the set $S = \\{1, 2, \\ldots, 10\\}$, and 4 numbers are randomly drawn from $S$. She wins a prize if at least 2 of her numbers match the drawn numbers, and wins the grand prize if all 4 match. The goal is to compute the conditional probability $P(\\text{grand prize} \\mid \\text{won a prize})$, expressed as $\\frac{m}{n}$ in lowest terms, and then find $m + n$.",
#       "direct_dependent_steps": null,
#       "node": "Jen picks 4 distinct numbers from $S = \\{1,2,\\ldots,10\\}$; 4 numbers are drawn uniformly at random from $S$. She wins a prize if at least 2 of her numbers match the drawn numbers, and wins the grand prize if all 4 match. Find $m+n$ where $P(\\text{grand prize} \\mid \\text{prize}) = \\frac{m}{n}$ with $\\gcd(m,n)=1$."
#     },
#     {
#       "step_id": 2,
# ...

# %%
df
# Out:
#                       id   dataset                             model  seed  \
# 0      aime2024-2024-I-4  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1005
# 1      aime2024-2024-I-4  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1001
# 2      aime2024-2024-I-4  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1002
# 3      aime2024-2024-I-4  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1007
# 4      aime2024-2024-I-4  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1000
# ..                   ...       ...                               ...   ...
# 235  aime2024-2024-II-14  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1003
# 236    aime2024-2024-I-5  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1002
# 237  aime2024-2024-II-10  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1004
# 238  aime2024-2024-II-10  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1005
# 239  aime2024-2024-II-14  aime2024  Qwen/Qwen3-30B-A3B-Instruct-2507  1004
#
#                                               question gold  \
# ...
